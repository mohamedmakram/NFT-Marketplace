# %%
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/dataset.csv')

# %%
df.head()
# Out:
#                 title                  name         creator  \
# 0     30 min Drawings            Giant Frog      kristyglas
# 1  Experimental Video          Biospecimens  juliakponsford
# 2            Sexy Art             long legs         badsexy
# 3         Dream World  A Guide in my Dreams         yoslehz
# 4         Dream World       Silent Observer         yoslehz
#
#                                        art_series  price     symbol   type  \
# 0           kristyglas_30-min-drawings_giant-frog   50.0  SWAP.HIVE  PHOTO
# 1  juliakponsford_experimental-video_biospecimens  500.0  SWAP.HIVE  VIDEO
# 2                      badsexy_sexy-art_long-legs   10.0  SWAP.HIVE  PHOTO
# 3        yoslehz_dream-world_a-guide-in-my-dreams   20.0  SWAP.HIVE  PHOTO
# 4             yoslehz_dream-world_silent-observer   20.0  SWAP.HIVE    GIF
#
#    likes   nsfw  tokens  year  rights  royalty  \
# 0      2  False      30  2020       1        0
# 1      0  False       1  2020       1        0
# ...

# %%
df.shape
# Out:
# (4189, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4189 entries, 0 to 4188
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       4189 non-null   object
#  1   name        4189 non-null   object
#  2   creator     4189 non-null   object
#  3   art_series  4189 non-null   object
#  4   price       4189 non-null   float64
#  5   symbol      4189 non-null   object
#  6   type        4189 non-null   object
#  7   likes       4189 non-null   int64
#  8   nsfw        4189 non-null   bool
#  9   tokens      4189 non-null   int64
#  10  year        4189 non-null   int64
#  11  rights      4189 non-null   int64
#  12  royalty     4189 non-null   int64
#  13  cid         4189 non-null   object
#  14  path        4189 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(8)
# memory usage: 462.4+ KB

# %%
df.isna().sum()
# Out:
# title         0
# name          0
# creator       0
# art_series    0
# price         0
# symbol        0
# type          0
# likes         0
# nsfw          0
# tokens        0
# year          0
# rights        0
# royalty       0
# cid           0
# path          0
# dtype: int64

# %%
# print the profile report provided by pandas_profiling 
pandas_profiling.ProfileReport(df, minimal=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-06-12 21:28:58.049380&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# > As pandas profile provides, we would drop the columns 'symbol' and 'royalty' as they contain a fixed value of SWAP.HIVE in the case of symbol and 0 in the case of royalty

# %%
df.drop(["symbol","royalty"], axis=1, inplace=True)

# %%
df
# Out:
#                                                 title  \
# 0                                     30 min Drawings
# 1                                  Experimental Video
# 2                                            Sexy Art
# 3                                         Dream World
# 4                                         Dream World
# ...                                               ...
# 4184                                 Abstract Erotica
# 4185                                          GIF art
# 4186                                              Eye
# 4187                                         HIVE ART
# 4188  fine arts -  high resolution printable artworks
#
#                                       name         creator  \
# 0                               Giant Frog      kristyglas
# 1                             Biospecimens  juliakponsford
# 2                                long legs         badsexy
# 3                     A Guide in my Dreams         yoslehz
# ...

# %% [markdown]
# > # NudeNet Classifier

# %% [markdown]
# > [How to detect nudity](https://ourcodeworld.com/articles/read/1347/how-to-detect-nudity-nudity-detection-nsfw-content-with-machine-learning-using-nudenet-in-python)?!

# %%
# !pip install --upgrade nudenet

# %%
from nudenet import NudeClassifier

# %%
classifier = NudeClassifier()

# %% [markdown]
# > "InvalidProtobuf: [ONNXRuntimeError] : 7 : INVALID_PROTOBUF : Load model from C:\Users\osama\.NudeNet/classifier_model.onnx failed:Protobuf parsing failed." issue is solved [here](https://stackoverflow.com/questions/70696761/python-nsfw-detection-module-nudenet-not-longer-working)

# %%
img = df[(df["type"] == 'PHOTO')].pop('path')

# %%
img
# Out:
# 0       ./dataset/image/QmegjZDN2gyD9A6cG4efj8DwbLLGTW...
# 2       ./dataset/image/QmaifAjZTJd8jTxNrwSoGWmFpbPYcs...
# 3       ./dataset/image/QmUTicJApSyByFb7sgsNa6cz8MG5RK...
# 6       ./dataset/image/QmT36BPdeJWNEdUr566z4DYGWxXqrD...
# 9       ./dataset/image/QmWQGXNu47pecHGfEatd3ATakphq5z...
#                               ...
# 4182    ./dataset/image/Qmbk1o7v6gxu9nVAPNfji1gWbQBT4J...
# 4183    ./dataset/image/QmYE2JsNxWbfqg3sYAfsxo84UkqBRi...
# 4184    ./dataset/image/QmeNbzcYHKDzZFTuY3PqBPr5WGKMGm...
# 4186    ./dataset/image/QmWTT58erwH6Vtv8UJNNM6mmWuwZNs...
# 4188    ./dataset/image/QmNYLy1vRaRYoGRMVmheRgMxPAcrUu...
# Name: path, Length: 3071, dtype: object

# %%
img.value_counts().sum()
# Out:
# 3071

# %%
images = list(img)

# %%
images
# Out:
# ['./dataset/image/QmegjZDN2gyD9A6cG4efj8DwbLLGTW6isDGadNC2yVJHfH.jpg',
#  './dataset/image/QmaifAjZTJd8jTxNrwSoGWmFpbPYcszMF4ZcZDBwpRR4v4.jpeg',
#  './dataset/image/QmUTicJApSyByFb7sgsNa6cz8MG5RKsHvGLP61gxSF3JsN.jpeg',
#  './dataset/image/QmT36BPdeJWNEdUr566z4DYGWxXqrDSeoA7zCHbKw8528w.png',
#  './dataset/image/QmWQGXNu47pecHGfEatd3ATakphq5zXVrzs5unYYK4VR1c.png',
#  './dataset/image/Qma6eHAWkXhrkHsfCHrYJNkuPoUAFrSjg2a6Xk2sCM7CBd.jpeg',
#  './dataset/image/QmeTAUBQUoqekVQBhEFqdCSAjCVX9ShTALx58w74mscf1a.jpeg',
#  './dataset/image/QmUmwLohsrgjHac27XQ7eWCkLS4VP35uUtT4jLqyo4rMyX.jpeg',
#  './dataset/image/QmWSozMKfzNE43WoAmcf5QdL3ptrmBTPJdxPxeggojeMdT.png',
#  './dataset/image/QmfDRZnYUtM96U8AgNbS9bqgpahvPSDrXs2vhfsJKK1PD5.png',
#  './dataset/image/QmSuqPZsf9xxcEkdDQpcNnJ5HZC3tacwsmPtmkrZ97LL8a.png',
#  './dataset/image/QmbJ5uAYt3PDjEHZNoodeyjpPM7CPp93aTWT3SshbS5YFa.png',
#  './dataset/image/QmaWvdqVZQeQXqSfR1HwPgWUUp1rfvDCQKvcc3gouhfbRm.png',
# ...

# %% [markdown]
# > See the issue solved [here](https://stackoverflow.com/questions/25705773/image-cropping-tool-python)

# %%
from PIL import Image

Image.MAX_IMAGE_PIXELS = None

# %%
img_lst = []
for image in images:
    classes = classifier.classify(image)
    for c in classes:
        img_lst.append(classes[c]['unsafe'])
# Out:
# ERROR:root:Error reading ./dataset/image/QmPaD3rSXvdQNwwxFPdTvWmKCW6ToV5j8hjVcTMwAX7bJ1.webp cannot identify image file './dataset/image/QmPaD3rSXvdQNwwxFPdTvWmKCW6ToV5j8hjVcTMwAX7bJ1.webp'
# Traceback (most recent call last):
#   File "C:\Users\osama\anaconda3\lib\site-packages\nudenet\image_utils.py", line 133, in load_images
#     image = load_img(img_path, target_size=image_size)
#   File "C:\Users\osama\anaconda3\lib\site-packages\nudenet\image_utils.py", line 54, in load_img
#     img = pil_image.open(path)
#   File "C:\Users\osama\anaconda3\lib\site-packages\PIL\Image.py", line 3008, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file './dataset/image/QmPaD3rSXvdQNwwxFPdTvWmKCW6ToV5j8hjVcTMwAX7bJ1.webp'
# ERROR:root:Error reading ./dataset/image/QmQhsQEa3A4UFEtgDyNyfkyEYK2MSygY9d8soVYeg1QaAP.webp cannot identify image file './dataset/image/QmQhsQEa3A4UFEtgDyNyfkyEYK2MSygY9d8soVYeg1QaAP.webp'
# Traceback (most recent call last):
# ...

# %%
img_lst
# Out:
# [0.004343247506767511,
#  0.8988715410232544,
#  0.013533039949834347,
#  0.3826743960380554,
#  0.1024426743388176,
#  0.02939988300204277,
#  0.9144554734230042,
#  0.0042862133122980595,
#  0.017948677763342857,
#  0.11021944880485535,
#  0.6837023496627808,
#  0.0044791982509195805,
#  0.00410918565467,
#  0.28629961609840393,
#  0.8365951180458069,
#  0.004448427818715572,
#  0.01866099052131176,
#  0.004475653171539307,
#  0.0580802746117115,
#  0.008078038692474365,
#  0.029370736330747604,
#  0.00884882640093565,
#  0.005933599546551704,
#  0.08580005168914795,
#  0.000999037059955299,
#  0.008598300628364086,
#  0.0003255590272601694,
#  0.0014751448761671782,
#  0.003856579540297389,
#  0.005027376115322113,
#  0.0030181817710399628,
#  0.6176418662071228,
#  0.015277223661541939,
#  0.17484208941459656,
#  0.001389536657370627,
#  0.014306840486824512,
#  0.0024157543666660786,
#  0.027428967878222466,
#  0.004526454955339432,
#  0.002970420755445957,
# ...

# %%
img_lst = [True if x >= 0.5 else False for x in img_lst]

# %%
img_lst
# Out:
# [False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
len(img_lst)
# Out:
# 3069

# %%
nsfw_df = pd.DataFrame(img_lst)

# %%
nsfw_df.rename(columns = {0:'NudeNet Classes'}, inplace = True)

# %%
nsfw_df
# Out:
#       NudeNet Classes
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 3064            False
# 3065            False
# 3066             True
# 3067            False
# 3068            False
#
# [3069 rows x 1 columns]

# %%
nsfw_df['NudeNet Classes'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False    94.75399152818508%
# True     5.246008471814923%
# Name: NudeNet Classes, dtype: object

# %%
df['nsfw'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False    96.65791358319407%
# True      3.34208641680592%
# Name: nsfw, dtype: object

# %% [markdown]
# > ## NSFW

# %%
# NSFW images only
nsfw_img = df[(df["type"] == 'PHOTO') & (df["nsfw"] == True)].pop('path')

# %%
# count the NSFW images
nsfw_img.value_counts().sum()
# Out:
# 118

# %%
nsfw_img
# Out:
# 2       ./dataset/image/QmaifAjZTJd8jTxNrwSoGWmFpbPYcs...
# 26      ./dataset/image/QmeddHYx6UDmTRRLDdCYmzVK4VjRGQ...
# 28      ./dataset/image/QmaM1zTWoiYwT5L4BNcaaRnB56ueai...
# 33      ./dataset/image/QmbQASW3MxD8AzDNaPCFunKJ8rVSSQ...
# 69      ./dataset/image/QmVyVXEKrwhTBo6QsvPqC4vSK5THwt...
#                               ...
# 3843    ./dataset/image/Qmazun61wXRfPjHDwwE7pDtRSuekeH...
# 3880    ./dataset/image/QmVDXWPYxQ97Z9vB6hEoTbWKgzrS1g...
# 4096    ./dataset/image/QmQ9BRvwJyysQDuEqsGNEfcA7na93v...
# 4145    ./dataset/image/QmQ9BRvwJyysQDuEqsGNEfcA7na93v...
# 4160    ./dataset/image/QmXjhH7XLddZdssnSnj9CxYt12WRqm...
# Name: path, Length: 118, dtype: object

# %%
nsfw_images = list(nsfw_img)

# %%
nsfw_lst = []
for image in nsfw_images:
    classes = classifier.classify(image)
    for c in classes:
        nsfw_lst.append(classes[c]['unsafe'])

# %%
nsfw_lst
# Out:
# [0.8988715410232544,
#  0.004448427818715572,
#  0.004475653171539307,
#  0.005933599546551704,
#  0.015517371706664562,
#  0.00629818718880415,
#  0.9077731370925903,
#  0.013513498939573765,
#  0.10426881164312363,
#  0.01607794128358364,
#  0.0062983958050608635,
#  0.0028110004495829344,
#  0.00514032319188118,
#  0.0044878688640892506,
#  0.019648518413305283,
#  0.0021631193812936544,
#  0.003202255116775632,
#  0.004316782113164663,
#  0.004547148011624813,
#  0.001979697961360216,
#  0.004926268011331558,
#  0.042955461889505386,
#  0.005233737174421549,
#  0.05616810545325279,
#  0.9999783039093018,
#  0.9993065595626831,
#  0.005382058210670948,
#  0.03252659738063812,
#  0.9842065572738647,
#  0.13866372406482697,
#  0.00893819984048605,
#  0.9985779523849487,
#  0.007352818269282579,
#  0.018430044874548912,
#  0.652789294719696,
#  0.009776201099157333,
#  0.009421014226973057,
#  0.03870416060090065,
#  0.03349130600690842,
#  0.07104223221540451,
# ...

# %%
nsfw_lst = [True if x >= 0.5 else False for x in nsfw_lst]

# %%
nsfw_lst
# Out:
# [True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
# ...

# %%
len(nsfw_lst)
# Out:
# 118

# %%
nsfw_df = pd.DataFrame(nsfw_lst)

# %%
nsfw_df.rename(columns = {0:'NudeNet Classes'}, inplace = True)

# %%
nsfw_df
# Out:
#      NudeNet Classes
# 0               True
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 113            False
# 114             True
# 115            False
# 116            False
# 117            False
#
# [118 rows x 1 columns]

# %%
nsfw_df['NudeNet Classes'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False    78.8135593220339%
# True     21.1864406779661%
# Name: NudeNet Classes, dtype: object
